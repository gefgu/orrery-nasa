# %%
import pandas as pd

# %%
df = pd.read_csv("data/satellite_data.csv")
df.head()
# Out:
#     OBJECT_NAME  OBJECT_ID                       EPOCH  MEAN_MOTION  \
# 0   CALSPHERE 1  1964-063C  2024-10-04T21:04:06.723840    13.753923
# 1   CALSPHERE 2  1964-063E  2024-10-04T21:20:37.934880    13.528209
# 2         LCS 1  1965-034C  2024-10-04T20:44:33.029952     9.893067
# 3     TEMPSAT 1  1965-065E  2024-10-04T20:36:45.512640    13.335324
# 4  CALSPHERE 4A  1965-065H  2024-10-04T20:04:34.135680    13.361109
#
#    ECCENTRICITY  INCLINATION  RA_OF_ASC_NODE  ARG_OF_PERICENTER  MEAN_ANOMALY  \
# 0      0.002531      90.2077         57.7181            13.2889      140.5397
# 1      0.001716      90.2215         61.4004           223.8250      307.5836
# 2      0.000814      32.1379        209.8915            78.6346      281.5066
# 3      0.006918      89.9646        213.6337           189.0694      232.1401
# 4      0.007081      89.9358        127.4565            54.7174       75.9291
#
#    EPHEMERIS_TYPE CLASSIFICATION_TYPE  NORAD_CAT_ID  ELEMENT_SET_NO  \
# ...

# %%
df.columns
# Out:
# Index(['OBJECT_NAME', 'OBJECT_ID', 'EPOCH', 'MEAN_MOTION', 'ECCENTRICITY',
#        'INCLINATION', 'RA_OF_ASC_NODE', 'ARG_OF_PERICENTER', 'MEAN_ANOMALY',
#        'EPHEMERIS_TYPE', 'CLASSIFICATION_TYPE', 'NORAD_CAT_ID',
#        'ELEMENT_SET_NO', 'REV_AT_EPOCH', 'BSTAR', 'MEAN_MOTION_DOT',
#        'MEAN_MOTION_DDOT'],
#       dtype='object')
